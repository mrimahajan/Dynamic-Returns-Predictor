# %%
import pandas as pd
import numpy as np
import pickle
import os
from scipy.stats import skew,kurtosis
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from advanced_analysis_package import variable_treatment,analyze

# %%
from openpyxl import load_workbook,Workbook

# %%
os.chdir('../output_data/')

# %%
df = pd.read_csv('train_v01.csv',header=0)

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev_Close', 'Open', 'High_pct_change',
#        'Low_pct_change', 'Last_pct_change', 'Close', 'VWAP_pct_change',
#        ...
#        'Voltality_500', 'return_1d', 'return_2d', 'return_3d', 'return_4d',
#        'return_5d', 'Voltality', 'Open_pct_change', 'Prev_Close_pct_change',
#        'actual_return'],
#       dtype='object', length=161)

# %%
os.chdir('../pickles')
numerical = pickle.load(open('numerical.pickle','rb'))
categorical = pickle.load(open('categorical.pickle','rb'))

# %%
os.chdir('../Statistics')

# %%
ignore_cols = ['Symbol','Series','Date','Prev_Close','Open','Close','Prev_Close_min','Prev_Close_max']

# %%
def automatic_outlier_treatment(data,s):
    
    lower_limit = data[s].quantile(q=.25)-1.5*(data[s].quantile(q=.75)-data[s].quantile(q=.25))
    upper_limit = data[s].quantile(q=.75)+1.5*(data[s].quantile(q=.75)-data[s].quantile(q=.25))

    frac_lower = float(np.unique(np.array(data.loc[(data[s].notnull()) & (data[s] < lower_limit),s]).shape[0]))/data.shape[0]
    frac_upper = float(np.unique(np.array(data.loc[(data[s].notnull()) & (data[s] > upper_limit),s]).shape[0]))/data.shape[0]

    p1,low_sigma3,low_sigma2 = data[s].quantile(q=.01),data[s].mean()-3*data[s].std(),data[s].mean()-2*data[s].std()
    p99,high_sigma3,high_sigma2 = data[s].quantile(q=.99),data[s].mean()+3*data[s].std(),data[s].mean()+2*data[s].std()
    p5,p95 = data[s].quantile(q=.05),data[s].quantile(q=.95)
    minima,maxima = data[s].min(),data[s].max()

    #deriving lower limit in case of aggresive treatment
    if low_sigma3 >= minima:
        b = min(p1,low_sigma3)
    elif low_sigma2>= minima:
        b = min(p1,low_sigma2)
    else:
        b=p1

    #deriving upper limit in case of aggresive treatment
    if high_sigma3 <= maxima:
        a = max(p99,high_sigma3)
    elif high_sigma2<= maxima:
        a = max(p99,high_sigma2)
    else:
        a=p99

    outlier_treatment = ''

    #lower end outlier treatment
    if frac_lower<=.05:
        variable_treatment.capping_and_flooring(data,s,a,b,high=False,low=True)
        if b==p1:
            outlier_treatment+='flooring at p1,'
        elif b==low_sigma2:
            outlier_treatment+='flooring at sigma2,'
        elif b==low_sigma3:
            outlier_treatment+='flooring at sigma3,'
    else:
        try:
            variable_treatment.exponential_smoothning(data,s,low=True,high=False)
            outlier_treatment+='lower line exponential smoothing,'
        except:
            pass

    #higher end outlier treatment
    if frac_upper<=.05:
        variable_treatment.capping_and_flooring(data,s,a,b,high=True,low=False)
        if b==p1:
            outlier_treatment+='capping at p99'
        elif b==low_sigma2:
            outlier_treatment+='capping at sigma2'
        elif b==low_sigma3:
            outlier_treatment+='Capping at sigma3'
    else:
        try:
            variable_treatment.exponential_smoothning(data,s,low=False,high=True)
            outlier_treatment+='higher line exponential smoothing'
        except:
            pass

    return outlier_treatment

# %%
numerical,categorical = analyze.numerical_categorical_division(df.drop(ignore_cols,axis=1))

# %%
categorical
# Out:
# ['Sector']

# %%
numerical = [x for x in numerical if (x != 'actual_return' and x not in categorical)]

# %%
df[numerical].dtypes
# Out:
# High_pct_change                  float64
# Low_pct_change                   float64
# Last_pct_change                  float64
# VWAP_pct_change                  float64
# Volume_pct_change                float64
# Turnover_pct_change              float64
# Trades_pct_change                float64
# Deliverable_Volume_pct_change    float64
# pct_Deliverble_pct_change        float64
# Open_nifty_pct_change            float64
# High_nifty_pct_change            float64
# Low_nifty_pct_change             float64
# Close_nifty_pct_change           float64
# Volume_nifty_pct_change          float64
# Turnover_nifty_pct_change        float64
# Open_auto_pct_change             float64
# High_auto_pct_change             float64
# Low_auto_pct_change              float64
# Close_auto_pct_change            float64
# Volume_auto_pct_change           float64
# Turnover_auto_pct_change         float64
# Open_bank_pct_change             float64
# High_bank_pct_change             float64
# Low_bank_pct_change              float64
# Close_bank_pct_change            float64
# Volume_bank_pct_change           float64
# Turnover_bank_pct_change         float64
# Open_fmcg_pct_change             float64
# High_fmcg_pct_change             float64
# Low_fmcg_pct_change              float64
#                                   ...
# return_3d_pharma                 float64
# return_4d_pharma                 float64
# return_5d_pharma                 float64
# Voltality_pharma                 float64
# return_1d_realty                 float64
# return_2d_realty                 float64
# return_3d_realty                 float64
# return_4d_realty                 float64
# return_5d_realty                 float64
# Voltality_realty                 float64
# return_1d_psu                    float64
# return_2d_psu                    float64
# return_3d_psu                    float64
# return_4d_psu                    float64
# return_5d_psu                    float64
# Voltality_psu                    float64
# return_1d_500                    float64
# return_2d_500                    float64
# return_3d_500                    float64
# return_4d_500                    float64
# return_5d_500                    float64
# Voltality_500                    float64
# return_1d                        float64
# return_2d                        float64
# return_3d                        float64
# return_4d                        float64
# return_5d                        float64
# Voltality                        float64
# Open_pct_change                  float64
# Prev_Close_pct_change            float64
# Length: 151, dtype: object

# %%
edd_df = pd.read_excel('report.xlsx',sheet_name='edd_price_prediction',header=0)

# %%
edd_df['outlier_treatment'] = ''
for col in numerical:
    edd_df.loc[edd_df['Var']==col,'outlier_treatment']=automatic_outlier_treatment(df,col)

# %%
numerical
# Out:
# ['High_pct_change',
#  'Low_pct_change',
#  'Last_pct_change',
#  'VWAP_pct_change',
#  'Volume_pct_change',
#  'Turnover_pct_change',
#  'Trades_pct_change',
#  'Deliverable_Volume_pct_change',
#  'pct_Deliverble_pct_change',
#  'Open_nifty_pct_change',
#  'High_nifty_pct_change',
#  'Low_nifty_pct_change',
#  'Close_nifty_pct_change',
#  'Volume_nifty_pct_change',
#  'Turnover_nifty_pct_change',
#  'Open_auto_pct_change',
#  'High_auto_pct_change',
#  'Low_auto_pct_change',
#  'Close_auto_pct_change',
#  'Volume_auto_pct_change',
#  'Turnover_auto_pct_change',
#  'Open_bank_pct_change',
#  'High_bank_pct_change',
#  'Low_bank_pct_change',
#  'Close_bank_pct_change',
#  'Volume_bank_pct_change',
#  'Turnover_bank_pct_change',
#  'Open_fmcg_pct_change',
#  'High_fmcg_pct_change',
#  'Low_fmcg_pct_change',
#  'Close_fmcg_pct_change',
#  'Volume_fmcg_pct_change',
#  'Turnover_fmcg_pct_change',
#  'Open_it_pct_change',
#  'High_it_pct_change',
#  'Low_it_pct_change',
#  'Close_it_pct_change',
#  'Volume_it_pct_change',
#  'Turnover_it_pct_change',
#  'Open_media_pct_change',
#  'High_media_pct_change',
#  'Low_media_pct_change',
#  'Close_media_pct_change',
#  'Volume_media_pct_change',
#  'Turnover_media_pct_change',
#  'Open_metal_pct_change',
#  'High_metal_pct_change',
#  'Low_metal_pct_change',
#  'Close_metal_pct_change',
#  'Volume_metal_pct_change',
#  'Turnover_metal_pct_change',
#  'Open_pharma_pct_change',
#  'High_pharma_pct_change',
#  'Low_pharma_pct_change',
#  'Close_pharma_pct_change',
#  'Volume_pharma_pct_change',
#  'Turnover_pharma_pct_change',
#  'Open_realty_pct_change',
#  'High_realty_pct_change',
#  'Low_realty_pct_change',
#  'Close_realty_pct_change',
#  'Volume_realty_pct_change',
#  'Turnover_realty_pct_change',
#  'Open_psu_pct_change',
#  'High_psu_pct_change',
#  'Low_psu_pct_change',
#  'Close_psu_pct_change',
#  'Volume_psu_pct_change',
#  'Turnover_psu_pct_change',
#  'Open_500_pct_change',
#  'High_500_pct_change',
#  'Low_500_pct_change',
#  'Close_500_pct_change',
#  'Volume_500_pct_change',
#  'Turnover_500_pct_change',
#  'Prev_Close_max_ratio',
#  'Prev_Close_min_ratio',
#  'return_1d_nifty',
#  'return_2d_nifty',
#  'return_3d_nifty',
#  'return_4d_nifty',
#  'return_5d_nifty',
#  'Voltality_nifty',
#  'return_1d_auto',
#  'return_2d_auto',
#  'return_3d_auto',
#  'return_4d_auto',
#  'return_5d_auto',
#  'Voltality_auto',
#  'return_1d_bank',
#  'return_2d_bank',
#  'return_3d_bank',
#  'return_4d_bank',
#  'return_5d_bank',
#  'Voltality_bank',
#  'return_1d_fmcg',
#  'return_2d_fmcg',
#  'return_3d_fmcg',
#  'return_4d_fmcg',
#  'return_5d_fmcg',
#  'Voltality_fmcg',
#  'return_1d_it',
#  'return_2d_it',
#  'return_3d_it',
#  'return_4d_it',
#  'return_5d_it',
#  'Voltality_it',
#  'return_1d_media',
#  'return_2d_media',
#  'return_3d_media',
#  'return_4d_media',
#  'return_5d_media',
#  'Voltality_media',
#  'return_1d_metal',
#  'return_2d_metal',
#  'return_3d_metal',
#  'return_4d_metal',
#  'return_5d_metal',
#  'Voltality_metal',
#  'return_1d_pharma',
#  'return_2d_pharma',
#  'return_3d_pharma',
#  'return_4d_pharma',
#  'return_5d_pharma',
#  'Voltality_pharma',
#  'return_1d_realty',
#  'return_2d_realty',
#  'return_3d_realty',
#  'return_4d_realty',
#  'return_5d_realty',
#  'Voltality_realty',
#  'return_1d_psu',
#  'return_2d_psu',
#  'return_3d_psu',
#  'return_4d_psu',
#  'return_5d_psu',
#  'Voltality_psu',
#  'return_1d_500',
#  'return_2d_500',
#  'return_3d_500',
#  'return_4d_500',
#  'return_5d_500',
#  'Voltality_500',
#  'return_1d',
#  'return_2d',
#  'return_3d',
#  'return_4d',
#  'return_5d',
#  'Voltality',
#  'Open_pct_change',
#  'Prev_Close_pct_change']

# %%
edd_df['outlier_treatment'].value_counts()
# Out:
# flooring at sigma3,Capping at sigma3                111
# flooring at p1,capping at p99                        28
# flooring at p1,higher line exponential smoothing     11
#                                                       2
# flooring at sigma2,capping at sigma2                  1
# Name: outlier_treatment, dtype: int64

# %%
wb = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx',engine='openpyxl')
writer.book = wb
edd_df.to_excel(writer,sheet_name='edd_price_prediction',index=False)
writer.save()
writer.close()

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_v02.csv',index=False)

# %%
df = pd.read_csv('train_v03.csv',header=0)

# %%
numerical,categorical = analyze.numerical_categorical_division(df.drop(ignore_cols,axis=1))

# %%
for col in numerical:
    df[col] = df[col].apply(lambda x : x if np.abs(x) <= 1 else np.sign(x)*1)

# %%
categorical
# Out:
# ['Sector']

# %%
numerical
# Out:
# ['High_pct_change',
#  'Low_pct_change',
#  'Last_pct_change',
#  'VWAP_pct_change',
#  'Volume_pct_change',
#  'Turnover_pct_change',
#  'Trades_pct_change',
#  'Deliverable_Volume_pct_change',
#  'pct_Deliverble_pct_change',
#  'Open_nifty_pct_change',
#  'High_nifty_pct_change',
#  'Low_nifty_pct_change',
#  'Close_nifty_pct_change',
#  'Volume_nifty_pct_change',
#  'Turnover_nifty_pct_change',
#  'Open_auto_pct_change',
#  'High_auto_pct_change',
#  'Low_auto_pct_change',
#  'Close_auto_pct_change',
#  'Volume_auto_pct_change',
#  'Turnover_auto_pct_change',
#  'Open_bank_pct_change',
#  'High_bank_pct_change',
#  'Low_bank_pct_change',
#  'Close_bank_pct_change',
#  'Volume_bank_pct_change',
#  'Turnover_bank_pct_change',
#  'Open_fmcg_pct_change',
#  'High_fmcg_pct_change',
#  'Low_fmcg_pct_change',
#  'Close_fmcg_pct_change',
#  'Volume_fmcg_pct_change',
#  'Turnover_fmcg_pct_change',
#  'Open_it_pct_change',
#  'High_it_pct_change',
#  'Low_it_pct_change',
#  'Close_it_pct_change',
#  'Volume_it_pct_change',
#  'Turnover_it_pct_change',
#  'Open_media_pct_change',
#  'High_media_pct_change',
#  'Low_media_pct_change',
#  'Close_media_pct_change',
#  'Volume_media_pct_change',
#  'Turnover_media_pct_change',
#  'Open_metal_pct_change',
#  'High_metal_pct_change',
#  'Low_metal_pct_change',
#  'Close_metal_pct_change',
#  'Volume_metal_pct_change',
#  'Turnover_metal_pct_change',
#  'Open_pharma_pct_change',
#  'High_pharma_pct_change',
#  'Low_pharma_pct_change',
#  'Close_pharma_pct_change',
#  'Volume_pharma_pct_change',
#  'Turnover_pharma_pct_change',
#  'Open_realty_pct_change',
#  'High_realty_pct_change',
#  'Low_realty_pct_change',
#  'Close_realty_pct_change',
#  'Volume_realty_pct_change',
#  'Turnover_realty_pct_change',
#  'Open_psu_pct_change',
#  'High_psu_pct_change',
#  'Low_psu_pct_change',
#  'Close_psu_pct_change',
#  'Volume_psu_pct_change',
#  'Turnover_psu_pct_change',
#  'Open_500_pct_change',
#  'High_500_pct_change',
#  'Low_500_pct_change',
#  'Close_500_pct_change',
#  'Volume_500_pct_change',
#  'Turnover_500_pct_change',
#  'Prev_Close_max_ratio',
#  'Prev_Close_min_ratio',
#  'return_1d_nifty',
#  'return_2d_nifty',
#  'return_3d_nifty',
#  'return_4d_nifty',
#  'return_5d_nifty',
#  'Voltality_nifty',
#  'return_1d_auto',
#  'return_2d_auto',
#  'return_3d_auto',
#  'return_4d_auto',
#  'return_5d_auto',
#  'Voltality_auto',
#  'return_1d_bank',
#  'return_2d_bank',
#  'return_3d_bank',
#  'return_4d_bank',
#  'return_5d_bank',
#  'Voltality_bank',
#  'return_1d_fmcg',
#  'return_2d_fmcg',
#  'return_3d_fmcg',
#  'return_4d_fmcg',
#  'return_5d_fmcg',
#  'Voltality_fmcg',
#  'return_1d_it',
#  'return_2d_it',
#  'return_3d_it',
#  'return_4d_it',
#  'return_5d_it',
#  'Voltality_it',
#  'return_1d_media',
#  'return_2d_media',
#  'return_3d_media',
#  'return_4d_media',
#  'return_5d_media',
#  'Voltality_media',
#  'return_1d_metal',
#  'return_2d_metal',
#  'return_3d_metal',
#  'return_4d_metal',
#  'return_5d_metal',
#  'Voltality_metal',
#  'return_1d_pharma',
#  'return_2d_pharma',
#  'return_3d_pharma',
#  'return_4d_pharma',
#  'return_5d_pharma',
#  'Voltality_pharma',
#  'return_1d_realty',
#  'return_2d_realty',
#  'return_3d_realty',
#  'return_4d_realty',
#  'return_5d_realty',
#  'Voltality_realty',
#  'return_1d_psu',
#  'return_2d_psu',
#  'return_3d_psu',
#  'return_4d_psu',
#  'return_5d_psu',
#  'Voltality_psu',
#  'return_1d_500',
#  'return_2d_500',
#  'return_3d_500',
#  'return_4d_500',
#  'return_5d_500',
#  'Voltality_500',
#  'return_1d',
#  'return_2d',
#  'return_3d',
#  'return_4d',
#  'return_5d',
#  'Voltality',
#  'Open_pct_change',
#  'Prev_Close_pct_change',
#  'actual_return']

# %%
df.to_csv('train_v03.csv',index=False)

# %% [markdown]
# # Imputation

# %%
conversion_dict={}

# %%
numerical
# Out:
# ['High_pct_change',
#  'Low_pct_change',
#  'Last_pct_change',
#  'VWAP_pct_change',
#  'Volume_pct_change',
#  'Turnover_pct_change',
#  'Trades_pct_change',
#  'Deliverable_Volume_pct_change',
#  'pct_Deliverble_pct_change',
#  'Open_nifty_pct_change',
#  'High_nifty_pct_change',
#  'Low_nifty_pct_change',
#  'Close_nifty_pct_change',
#  'Volume_nifty_pct_change',
#  'Turnover_nifty_pct_change',
#  'Open_auto_pct_change',
#  'High_auto_pct_change',
#  'Low_auto_pct_change',
#  'Close_auto_pct_change',
#  'Volume_auto_pct_change',
#  'Turnover_auto_pct_change',
#  'Open_bank_pct_change',
#  'High_bank_pct_change',
#  'Low_bank_pct_change',
#  'Close_bank_pct_change',
#  'Volume_bank_pct_change',
#  'Turnover_bank_pct_change',
#  'Open_fmcg_pct_change',
#  'High_fmcg_pct_change',
#  'Low_fmcg_pct_change',
#  'Close_fmcg_pct_change',
#  'Volume_fmcg_pct_change',
#  'Turnover_fmcg_pct_change',
#  'Open_it_pct_change',
#  'High_it_pct_change',
#  'Low_it_pct_change',
#  'Close_it_pct_change',
#  'Volume_it_pct_change',
#  'Turnover_it_pct_change',
#  'Open_media_pct_change',
#  'High_media_pct_change',
#  'Low_media_pct_change',
#  'Close_media_pct_change',
#  'Volume_media_pct_change',
#  'Turnover_media_pct_change',
#  'Open_metal_pct_change',
#  'High_metal_pct_change',
#  'Low_metal_pct_change',
#  'Close_metal_pct_change',
#  'Volume_metal_pct_change',
#  'Turnover_metal_pct_change',
#  'Open_pharma_pct_change',
#  'High_pharma_pct_change',
#  'Low_pharma_pct_change',
#  'Close_pharma_pct_change',
#  'Volume_pharma_pct_change',
#  'Turnover_pharma_pct_change',
#  'Open_realty_pct_change',
#  'High_realty_pct_change',
#  'Low_realty_pct_change',
#  'Close_realty_pct_change',
#  'Volume_realty_pct_change',
#  'Turnover_realty_pct_change',
#  'Open_psu_pct_change',
#  'High_psu_pct_change',
#  'Low_psu_pct_change',
#  'Close_psu_pct_change',
#  'Volume_psu_pct_change',
#  'Turnover_psu_pct_change',
#  'Open_500_pct_change',
#  'High_500_pct_change',
#  'Low_500_pct_change',
#  'Close_500_pct_change',
#  'Volume_500_pct_change',
#  'Turnover_500_pct_change',
#  'Prev_Close_max_ratio',
#  'Prev_Close_min_ratio',
#  'return_1d_nifty',
#  'return_2d_nifty',
#  'return_3d_nifty',
#  'return_4d_nifty',
#  'return_5d_nifty',
#  'Voltality_nifty',
#  'return_1d_auto',
#  'return_2d_auto',
#  'return_3d_auto',
#  'return_4d_auto',
#  'return_5d_auto',
#  'Voltality_auto',
#  'return_1d_bank',
#  'return_2d_bank',
#  'return_3d_bank',
#  'return_4d_bank',
#  'return_5d_bank',
#  'Voltality_bank',
#  'return_1d_fmcg',
#  'return_2d_fmcg',
#  'return_3d_fmcg',
#  'return_4d_fmcg',
#  'return_5d_fmcg',
#  'Voltality_fmcg',
#  'return_1d_it',
#  'return_2d_it',
#  'return_3d_it',
#  'return_4d_it',
#  'return_5d_it',
#  'Voltality_it',
#  'return_1d_media',
#  'return_2d_media',
#  'return_3d_media',
#  'return_4d_media',
#  'return_5d_media',
#  'Voltality_media',
#  'return_1d_metal',
#  'return_2d_metal',
#  'return_3d_metal',
#  'return_4d_metal',
#  'return_5d_metal',
#  'Voltality_metal',
#  'return_1d_pharma',
#  'return_2d_pharma',
#  'return_3d_pharma',
#  'return_4d_pharma',
#  'return_5d_pharma',
#  'Voltality_pharma',
#  'return_1d_realty',
#  'return_2d_realty',
#  'return_3d_realty',
#  'return_4d_realty',
#  'return_5d_realty',
#  'Voltality_realty',
#  'return_1d_psu',
#  'return_2d_psu',
#  'return_3d_psu',
#  'return_4d_psu',
#  'return_5d_psu',
#  'Voltality_psu',
#  'return_1d_500',
#  'return_2d_500',
#  'return_3d_500',
#  'return_4d_500',
#  'return_5d_500',
#  'Voltality_500',
#  'return_1d',
#  'return_2d',
#  'return_3d',
#  'return_4d',
#  'return_5d',
#  'Voltality',
#  'Open_pct_change',
#  'Prev_Close_pct_change',
#  'actual_return']

# %%
categorical
# Out:
# ['Sector']

# %%
for col in categorical:
    conversion_dict[col]=variable_treatment.make_dummies(df,col)

# %%
os.chdir('../pickles')

# %%
pickle.dump(conversion_dict,open('conversion_dict.pickle','wb'))
pickle.dump(numerical,open('numerical.pickle','wb'))
pickle.dump(categorical,open('categorical.pickle','wb'))

# %%
conversion_dict
# Out:
# {'Sector': ['Banking',
#   'Automobile',
#   'Consumer Goods',
#   'Energy - Oil & Gas',
#   'Metals',
#   'Information Technology',
#   'Financial Services',
#   'Pharmaceuticals',
#   'Cement',
#   'Energy - Power',
#   'Telecommunication',
#   'Construction',
#   'Media & Entertainment',
#   'Services - Shipping']}

# %%
imputation_cols = [col for col in df.columns if col not in numerical+['actual_return']+categorical]

# %%
imputation_cols
# Out:
# ['Date',
#  'Symbol',
#  'Series',
#  'Prev_Close',
#  'Open',
#  'Close',
#  'Prev_Close_max',
#  'Prev_Close_min',
#  'Sector_dum_Banking',
#  'Sector_dum_Automobile',
#  'Sector_dum_Consumer Goods',
#  'Sector_dum_Energy - Oil & Gas',
#  'Sector_dum_Metals',
#  'Sector_dum_Information Technology',
#  'Sector_dum_Financial Services',
#  'Sector_dum_Pharmaceuticals',
#  'Sector_dum_Cement',
#  'Sector_dum_Energy - Power',
#  'Sector_dum_Telecommunication',
#  'Sector_dum_Construction',
#  'Sector_dum_Media & Entertainment',
#  'Sector_dum_Services - Shipping']

# %%
df
# Out:
#        Prev_Close(in 10^5)  High_1d(in 10^5)  Low_1d(in 10^5)  \
# 11278             0.003392          0.003509         0.003365
# 46936             0.003177          0.003209         0.003136
# 16216             0.028807          0.030342         0.028601
# 64226             0.002457          0.002533         0.002450
# 36964             0.008550          0.008685         0.008500
# 72871             0.005073          0.005330         0.005050
# 41749             0.008535          0.008769         0.008485
# 59039             0.002249          0.002366         0.002230
# 50394             0.006273          0.006475         0.006233
# 24861             0.002827          0.002894         0.002755
# 84974             0.003688          0.003776         0.003585
# 65955             0.008729          0.009004         0.008686
# 23132             0.185517          0.191916         0.184696
# 60768             0.001310          0.001328         0.001280
# 904               0.003479          0.003552         0.003363
# 38693             0.002780          0.002823         0.002757
# 48665             0.008914          0.009105         0.008600
# 35235             0.001079          0.001095         0.001061
# 57310             0.001199          0.001230         0.001163
# 74600             0.003247          0.003331         0.003205
# 55581             0.042070          0.042564         0.041114
# 53852             0.012155          0.012620         0.012051
# 6091              0.022447          0.022700         0.021337
# 2633              0.008519          0.008681         0.008470
# 28319             0.009024          0.009349         0.008840
# 21403             0.040612          0.041300         0.039710
# 71142             0.002156          0.002197         0.002090
# 7820              0.049673          0.050650         0.048920
# 67684             0.025768          0.026390         0.025119
# 83245             0.006817          0.006950         0.006628
# ...                    ...               ...              ...
# 67981             0.021011          0.021471         0.020862
# 71439             0.004265          0.004415         0.004240
# 6388              0.026476          0.027680         0.026330
# 33803             0.029753          0.031300         0.029640
# 45504          101.004153           0.817212       1.034771             1
# 18242          101.004153           0.817212       0.913378             1
# 52420          101.004153           0.817212       0.920625             0
# 9846           101.004153           0.817212       0.779166             0
# 35532          101.004153           0.817212       1.224177             0
# 55878          101.004153           0.817212       0.563223             1
# 40317          101.004153           0.817212       0.997467             0
# 48962          101.004153           0.817212       1.202889             0
# 14784          101.004153           0.817212       0.332068             1
# 8117           101.004153           0.817212       0.921640             0
# 57607          101.004153           0.817212       0.723852             0
# 11575          101.004153           0.817212       0.822124             0
# 81813          101.004153           0.817212       0.869879             1
# 32074          101.004153           0.817212       0.492423             0
# 19971          101.004153           0.817212       0.983683             0
# 1201           101.004153           0.817212       1.192658             1
# 21700          101.004153           0.817212       1.346513             1
# 73168          101.004153           0.817212       0.793915             1
# 16513          101.004153           0.817212       0.336894             0
# 43775          101.004153           0.817212       0.650181             1
# 26887          101.004153           0.817212       0.657530             1
#
#        Sector_dum_1  Sector_dum_2  Sector_dum_3
# 11278             1             0             1
# 46936             1             0             0
# 16216             1             0             0
# 64226             0             0             0
# 36964             1             0             0
# 72871             1             0             0
# 41749             0             0             0
# 59039             0             1             0
# 50394             0             0             0
# 24861             0             1             0
# 84974             1             1             1
# 65955             1             1             0
# 23132             0             0             0
# 60768             0             0             1
# 904               1             0             1
# 38693             0             0             0
# 48665             0             1             0
# 35235             0             1             0
# 57310             0             0             1
# 74600             1             0             0
# 55581             0             0             0
# 53852             0             0             0
# 6091              0             0             0
# 2633              1             0             0
# 28319             1             0             0
# 21403             1             1             0
# 71142             0             1             0
# 7820              1             1             0
# 67684             1             0             0
# 83245             0             0             0
# ...             ...           ...           ...
# 67981             1             0             0
# 71439             0             1             0
# 6388              0             0             0
# 33803             0             0             0
# 85271             1             1             1
# 64523             0             0             0
# 28616             1             0             0
# 69710             0             0             0
# 66252             1             1             0
# 45504             0             1             0
# 18242             1             1             0
# 52420             0             1             1
# 9846              1             1             0
# 35532             0             1             0
# 55878             0             0             0
# 40317             1             1             0
# 48962             0             1             0
# 14784             0             1             0
# 8117              1             1             0
# 57607             0             0             1
# 11575             1             0             1
# 81813             1             0             0
# 32074             0             0             0
# 19971             0             1             0
# 1201              1             0             1
# 21700             1             1             0
# 73168             1             0             0
# 16513             1             0             0
# 43775             1             0             0
# 26887             0             0             1
#
# [85799 rows x 219 columns]

# %%
pickle.dump(imputation_cols,open('imputation_cols.pickle','wb'))

# %%
os.chdir('../Imputation_models')

# %%
for col in [x for x in numerical if x!='actual_return']:
    data = df[imputation_cols+[col]].dropna(subset=[col])
    x = np.array(data[imputation_cols])
    y = np.array(data[col])
    model = LinearRegression()
    model.fit(x,y)
    del x
    del y
    pickle.dump(model,open(col+'_impute.pickle','wb'))
    if df[col].isnull().any():
        indices = df.loc[df[col].isnull()].index.tolist()
        df.loc[indices,col]=np.array(model.predict(np.array(df.loc[indices,imputation_cols])))
        del indices
    del model
    print(col+' imputed')
# Out:
# Prev_Close(in 10^5) imputed
# High_1d(in 10^5) imputed
# Low_1d(in 10^5) imputed
# Last_1d(in 10^5) imputed
# VWAP_1d(in 10^5) imputed
# Volume_1d(in 10^9) imputed
# Turnover_1d(in 10^11) imputed
# Trades_1d(in 10^7) imputed
# Deliverable_Volume_1d(in 10^9) imputed
# pct_Deliverble_1d imputed
# Open_nifty_1d(in 10^5) imputed
# High_nifty_1d(in 10^5) imputed
# Low_nifty_1d(in 10^5) imputed
# Close_nifty_1d(in 10^5) imputed
# Volume_nifty_1d(in 10^9) imputed
# Turnover_nifty_1d(in 10^11) imputed
# Open_auto_1d(in 10^5) imputed
# High_auto_1d(in 10^5) imputed
# Low_auto_1d(in 10^5) imputed
# Close_auto_1d(in 10^5) imputed
# Open_bank_1d(in 10^5) imputed
# High_bank_1d(in 10^5) imputed
# Low_bank_1d(in 10^5) imputed
# Close_bank_1d(in 10^5) imputed
# Open_fmcg_1d(in 10^5) imputed
# High_fmcg_1d(in 10^5) imputed
# Low_fmcg_1d(in 10^5) imputed
# Close_fmcg_1d(in 10^5) imputed
# Open_it_1d(in 10^5) imputed
# High_it_1d(in 10^5) imputed
# Low_it_1d(in 10^5) imputed
# Close_it_1d(in 10^5) imputed
# Open_media_1d(in 10^4) imputed
# High_media_1d(in 10^4) imputed
# Low_media_1d(in 10^4) imputed
# Close_media_1d(in 10^4) imputed
# Open_metal_1d(in 10^4) imputed
# High_metal_1d(in 10^4) imputed
# Low_metal_1d(in 10^4) imputed
# Close_metal_1d(in 10^4) imputed
# Open_pharma_1d(in 10^5) imputed
# High_pharma_1d(in 10^5) imputed
# Low_pharma_1d(in 10^5) imputed
# Close_pharma_1d(in 10^5) imputed
# Open_realty_1d(in 10^3) imputed
# High_realty_1d(in 10^3) imputed
# Low_realty_1d(in 10^3) imputed
# Close_realty_1d(in 10^3) imputed
# Open_psu_1d(in 10^4) imputed
# High_psu_1d(in 10^4) imputed
# Low_psu_1d(in 10^4) imputed
# Close_psu_1d(in 10^4) imputed
# Open_500_1d(in 10^5) imputed
# High_500_1d(in 10^5) imputed
# Low_500_1d(in 10^4) imputed
# Close_500_1d(in 10^4) imputed
# return_1d_nifty imputed
# return_2d_nifty imputed
# return_3d_nifty imputed
# return_4d_nifty imputed
# return_5d_nifty imputed
# Voltality_nifty imputed
# return_1d_auto imputed
# return_2d_auto imputed
# return_3d_auto imputed
# return_4d_auto imputed
# return_5d_auto imputed
# Voltality_auto imputed
# return_1d_bank imputed
# return_2d_bank imputed
# return_3d_bank imputed
# return_4d_bank imputed
# return_5d_bank imputed
# Voltality_bank imputed
# return_1d_fmcg imputed
# return_2d_fmcg imputed
# return_3d_fmcg imputed
# return_4d_fmcg imputed
# return_5d_fmcg imputed
# Voltality_fmcg imputed
# return_1d_it imputed
# return_2d_it imputed
# return_3d_it imputed
# return_4d_it imputed
# return_5d_it imputed
# Voltality_it imputed
# return_1d_media imputed
# return_2d_media imputed
# return_3d_media imputed
# return_4d_media imputed
# return_5d_media imputed
# Voltality_media imputed
# return_1d_metal imputed
# return_2d_metal imputed
# return_3d_metal imputed
# return_4d_metal imputed
# return_5d_metal imputed
# Voltality_metal imputed
# return_1d_pharma imputed
# return_2d_pharma imputed
# return_3d_pharma imputed
# return_4d_pharma imputed
# return_5d_pharma imputed
# Voltality_pharma imputed
# return_1d_realty imputed
# return_2d_realty imputed
# return_3d_realty imputed
# return_4d_realty imputed
# return_5d_realty imputed
# Voltality_realty imputed
# return_1d_psu imputed
# return_2d_psu imputed
# return_3d_psu imputed
# return_4d_psu imputed
# return_5d_psu imputed
# Voltality_psu imputed
# return_1d_500 imputed
# return_2d_500 imputed
# return_3d_500 imputed
# return_4d_500 imputed
# return_5d_500 imputed
# Voltality_500 imputed
# return_1d imputed
# return_2d imputed
# return_3d imputed
# return_4d imputed
# return_5d imputed
# Voltality imputed
# Open_1d(in 10^5) imputed
# Volume_1d(in 10^9)_log imputed
# Turnover_1d(in 10^11)_log imputed
# Trades_1d(in 10^7)_log imputed
# Deliverable_Volume_1d(in 10^9)_log imputed
# pct_Deliverble_1d_sqr imputed
# pct_Deliverble_1d_cube imputed
# pct_Deliverble_1d_exp imputed
# Low_nifty_1d(in 10^5)_log imputed
# Close_nifty_1d(in 10^5)_log imputed
# Open_bank_1d(in 10^5)_log imputed
# High_bank_1d(in 10^5)_log imputed
# Low_bank_1d(in 10^5)_log imputed
# Close_bank_1d(in 10^5)_log imputed
# Open_it_1d(in 10^5)_sqr imputed
# Open_it_1d(in 10^5)_cube imputed
# Open_it_1d(in 10^5)_exp imputed
# High_it_1d(in 10^5)_sqr imputed
# High_it_1d(in 10^5)_cube imputed
# High_it_1d(in 10^5)_exp imputed
# Low_it_1d(in 10^5)_sqr imputed
# Low_it_1d(in 10^5)_cube imputed
# Low_it_1d(in 10^5)_exp imputed
# Close_it_1d(in 10^5)_sqr imputed
# Close_it_1d(in 10^5)_cube imputed
# Close_it_1d(in 10^5)_exp imputed
# Open_media_1d(in 10^4)_log imputed
# High_media_1d(in 10^4)_log imputed
# Low_media_1d(in 10^4)_log imputed
# Close_media_1d(in 10^4)_log imputed
# Open_pharma_1d(in 10^5)_sqr imputed
# Open_pharma_1d(in 10^5)_cube imputed
# Open_pharma_1d(in 10^5)_exp imputed
# High_pharma_1d(in 10^5)_sqr imputed
# High_pharma_1d(in 10^5)_cube imputed
# High_pharma_1d(in 10^5)_exp imputed
# Low_pharma_1d(in 10^5)_sqr imputed
# Low_pharma_1d(in 10^5)_cube imputed
# Low_pharma_1d(in 10^5)_exp imputed
# Close_pharma_1d(in 10^5)_sqr imputed
# Close_pharma_1d(in 10^5)_cube imputed
# Close_pharma_1d(in 10^5)_exp imputed
# Open_psu_1d(in 10^4)_sqr imputed
# High_psu_1d(in 10^4)_sqr imputed
# Low_psu_1d(in 10^4)_sqr imputed
# Close_psu_1d(in 10^4)_sqr imputed
# Open_500_1d(in 10^5)_log imputed
# High_500_1d(in 10^5)_log imputed
# Low_500_1d(in 10^4)_log imputed
# Close_500_1d(in 10^4)_log imputed
# return_1d_nifty_sqr imputed
# return_1d_nifty_cube imputed
# return_2d_nifty_sqr imputed
# return_2d_nifty_cube imputed
# return_3d_nifty_sqr imputed
# return_3d_nifty_cube imputed
# return_5d_nifty_sqr imputed
# Voltality_nifty_log imputed
# Voltality_auto_log imputed
# return_1d_fmcg_sqr imputed
# return_1d_fmcg_cube imputed
# return_2d_fmcg_sqr imputed
# return_2d_fmcg_cube imputed
# return_3d_fmcg_sqr imputed
# return_4d_fmcg_sqr imputed
# return_4d_fmcg_cube imputed
# return_5d_fmcg_sqr imputed
# return_5d_fmcg_cube imputed
# Voltality_fmcg_log imputed
# return_2d_it_sqr imputed
# return_2d_it_cube imputed
# return_4d_it_cube imputed
# Voltality_metal_log imputed
# return_1d_realty_cube imputed
# return_2d_realty_sqr imputed
# return_2d_realty_cube imputed
# Voltality_psu_log imputed
# return_1d_500_sqr imputed
# return_1d_500_cube imputed
# return_2d_500_sqr imputed
# return_2d_500_cube imputed
# return_3d_500_sqr imputed
# return_3d_500_cube imputed
# Voltality_500_log imputed
# Voltality_log imputed

# %%
df[[x for x in numerical if x!='actual_return']].isnull().any()
# Out:
# Prev_Close(in 10^5)               False
# High_1d(in 10^5)                  False
# Low_1d(in 10^5)                   False
# Last_1d(in 10^5)                  False
# VWAP_1d(in 10^5)                  False
# Volume_1d(in 10^9)                False
# Turnover_1d(in 10^11)             False
# Trades_1d(in 10^7)                False
# Deliverable_Volume_1d(in 10^9)    False
# pct_Deliverble_1d                 False
# Open_nifty_1d(in 10^5)            False
# High_nifty_1d(in 10^5)            False
# Low_nifty_1d(in 10^5)             False
# Close_nifty_1d(in 10^5)           False
# Volume_nifty_1d(in 10^9)          False
# Turnover_nifty_1d(in 10^11)       False
# Open_auto_1d(in 10^5)             False
# High_auto_1d(in 10^5)             False
# Low_auto_1d(in 10^5)              False
# Close_auto_1d(in 10^5)            False
# Open_bank_1d(in 10^5)             False
# High_bank_1d(in 10^5)             False
# Low_bank_1d(in 10^5)              False
# Close_bank_1d(in 10^5)            False
# Open_fmcg_1d(in 10^5)             False
# High_fmcg_1d(in 10^5)             False
# Low_fmcg_1d(in 10^5)              False
# Close_fmcg_1d(in 10^5)            False
# Open_it_1d(in 10^5)               False
# High_it_1d(in 10^5)               False
#                                   ...
# return_3d_nifty_cube              False
# return_5d_nifty_sqr               False
# Voltality_nifty_log               False
# Voltality_auto_log                False
# return_1d_fmcg_sqr                False
# return_1d_fmcg_cube               False
# return_2d_fmcg_sqr                False
# return_2d_fmcg_cube               False
# return_3d_fmcg_sqr                False
# return_4d_fmcg_sqr                False
# return_4d_fmcg_cube               False
# return_5d_fmcg_sqr                False
# return_5d_fmcg_cube               False
# Voltality_fmcg_log                False
# return_2d_it_sqr                  False
# return_2d_it_cube                 False
# return_4d_it_cube                 False
# Voltality_metal_log               False
# return_1d_realty_cube             False
# return_2d_realty_sqr              False
# return_2d_realty_cube             False
# Voltality_psu_log                 False
# return_1d_500_sqr                 False
# return_1d_500_cube                False
# return_2d_500_sqr                 False
# return_2d_500_cube                False
# return_3d_500_sqr                 False
# return_3d_500_cube                False
# Voltality_500_log                 False
# Voltality_log                     False
# Length: 213, dtype: bool

# %%
default_categorical
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1329f43d9bf0> in <module>()
# ----> 1 default_categorical
#
# NameError: name 'default_categorical' is not defined

# %%
df.drop(default_categorical,axis=1,inplace=True)

# %%
os.chdir('../output_data')

# %%
rename_dict = {col : col.replace(' ','_').replace('-','_').replace('&','_') for col in df.columns if '-' in col or ' ' in col}

# %%
rename_dict
# Out:
# {'Sector_dum_Consumer Goods': 'Sector_dum_Consumer_Goods',
#  'Sector_dum_Energy - Oil & Gas': 'Sector_dum_Energy___Oil___Gas',
#  'Sector_dum_Information Technology': 'Sector_dum_Information_Technology',
#  'Sector_dum_Financial Services': 'Sector_dum_Financial_Services',
#  'Sector_dum_Energy - Power': 'Sector_dum_Energy___Power',
#  'Sector_dum_Media & Entertainment': 'Sector_dum_Media___Entertainment',
#  'Sector_dum_Services - Shipping': 'Sector_dum_Services___Shipping'}

# %%
df.rename(rename_dict,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev_Close', 'Open', 'High_pct_change',
#        'Low_pct_change', 'Last_pct_change', 'Close', 'VWAP_pct_change',
#        ...
#        'Sector_dum_Metals', 'Sector_dum_Information_Technology',
#        'Sector_dum_Financial_Services', 'Sector_dum_Pharmaceuticals',
#        'Sector_dum_Cement', 'Sector_dum_Energy___Power',
#        'Sector_dum_Telecommunication', 'Sector_dum_Construction',
#        'Sector_dum_Media___Entertainment', 'Sector_dum_Services___Shipping'],
#       dtype='object', length=175)

# %%
df.to_csv('train_v04.csv',index=False)

# %%
df.isnull().any()
# Out:
# Date                                 False
# Symbol                               False
# Series                               False
# Prev_Close                           False
# Open                                 False
# High_pct_change                      False
# Low_pct_change                       False
# Last_pct_change                      False
# Close                                False
# VWAP_pct_change                      False
# Volume_pct_change                    False
# Turnover_pct_change                  False
# Trades_pct_change                    False
# Deliverable_Volume_pct_change        False
# pct_Deliverble_pct_change            False
# Sector                               False
# Open_nifty_pct_change                False
# High_nifty_pct_change                False
# Low_nifty_pct_change                 False
# Close_nifty_pct_change               False
# Volume_nifty_pct_change              False
# Turnover_nifty_pct_change            False
# Open_auto_pct_change                 False
# High_auto_pct_change                 False
# Low_auto_pct_change                  False
# Close_auto_pct_change                False
# Volume_auto_pct_change               False
# Turnover_auto_pct_change             False
# Open_bank_pct_change                 False
# High_bank_pct_change                 False
#                                      ...
# Voltality_psu                        False
# return_1d_500                        False
# return_2d_500                        False
# return_3d_500                        False
# return_4d_500                        False
# return_5d_500                        False
# Voltality_500                        False
# return_1d                            False
# return_2d                            False
# return_3d                            False
# return_4d                            False
# return_5d                            False
# Voltality                            False
# Open_pct_change                      False
# Prev_Close_pct_change                False
# actual_return                        False
# Sector_dum_Banking                   False
# Sector_dum_Automobile                False
# Sector_dum_Metals                    False
# Sector_dum_Information_Technology    False
# Sector_dum_Consumer_Goods            False
# Sector_dum_Energy___Oil_&_Gas        False
# Sector_dum_Financial_Services        False
# Sector_dum_Pharmaceuticals           False
# Sector_dum_Cement                    False
# Sector_dum_Energy___Power            False
# Sector_dum_Telecommunication         False
# Sector_dum_Chemicals                 False
# Sector_dum_Construction              False
# Sector_dum_Media_&_Entertainment     False
# Length: 175, dtype: bool
